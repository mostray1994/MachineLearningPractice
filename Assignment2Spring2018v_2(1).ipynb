# %% [markdown]
# <div style="text-align: center;">
# <h2>INFSCI 2915 Foundations- Machine Learning - Spring 2018 </h2>
# <h1 style="font-size: 250%;">Assignment #2</h1>
# <h3>Issued Monday, 2/26/2018; Due Monday, 11:59pm, 3/12/2018</h3>
# <h3>Total points: 100 </h3>
# </div>

# %%
# Type in your information in the double quotes
firstName = "Junxi"
lastName = "Huang"
pittID = "JUH80"

# %% [markdown]
# <h3>  Problem #1. Train Test Split [20 points]</h3>
# In this part, you should download **"Iris dataset"**. <br>
# Use a code below to download the  dataset:

# %%
from sklearn.datasets import load_iris
dataset=load_iris()
print(dataset.keys())
# Out:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names'])

# %% [markdown]
# <h4> Problem #1-1. </h4> Split iris dataset into training and test datasets. (use train_test_split function and random_state=0)
#
# - Report the shape of each (training and test) datasets. What is the proportion of each set?

# %%
#Write your narrative answer here
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test= train_test_split(dataset['data'], dataset['target'], random_state= 0)
print('shape of X_train_shape',X_train.shape)
print('shape of X_test_shape',X_test.shape)
print('shape of Y_train_shape',Y_train.shape)
print('shape of Y_test_shape',Y_test.shape)
# Out:
# shape of X_train_shape (112, 4)
# shape of X_test_shape (38, 4)
# shape of Y_train_shape (112,)
# shape of Y_test_shape (38,)

# %% [markdown]
# <h4> Problem #1-2. </h4>  Split iris dataset into training and test datasets. Make the proportion of training dataset 60% (use train_test_split function and random_state=0)
#
#
# - Report the shape of each (training and test) datasets.

# %%
#Write your narrative answer here
X_train, X_test, Y_train, Y_test= train_test_split(dataset['data'], dataset['target'], test_size=0.4,random_state= 0)
print('shape of X_train_shape',X_train.shape)
print('shape of X_test_shape',X_test.shape)
# Out:
# shape of X_train_shape (90, 4)
# shape of X_test_shape (60, 4)

# %% [markdown]
# <h4> Problem #1-3. </h4>  Split iris dataset into training and test datasets. Make the proportion of test dataset 33.3% (use train_test_split function and random_state=0)
#
#
# - Report the shape of each (training and test) dataset.

# %%
#Write your narrative answer here
X_train, X_test, Y_train, Y_test= train_test_split(dataset['data'], dataset['target'], test_size=0.333, random_state= 0)
print('shape of X_train_shape',X_train.shape)
print('shape of X_test_shape',X_test.shape)
# Out:
# shape of X_train_shape (100, 4)
# shape of X_test_shape (50, 4)

# %% [markdown]
# <h4> Problem #1-4. Random State </h4>
# Split iris dataset into training and test datasets, Use different Random State values (0,  10, 253, 1000, 0 and 10)
#
# - Analyze the shape and values of the train and test datasets  generated from different Random State values (you can use descriptive statistics)
#
# - What happens if you do not specify Random State?
#
# - What is a purpose of using Random State?

# %% [markdown]
# ##### for random state values is 0

# %%
#Write your narrative answer here
import pandas as pd
import numpy as np
X_train, X_test, Y_train, Y_test= train_test_split(dataset['data'], dataset['target'], random_state= 0)
dataFrame1=pd.DataFrame(X_train,columns=dataset.feature_names)
dataFrame1.describe(include='all')
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         112.000000        112.000000         112.000000
# mean            5.886607          3.051786           3.796429
# std             0.871314          0.436196           1.800697
# min             4.300000          2.000000           1.100000
# 25%             5.100000          2.800000           1.575000
# 50%             5.800000          3.000000           4.250000
# 75%             6.500000          3.300000           5.200000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        112.000000
# mean           1.222321
# std            0.782662
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.900000
# max            2.500000

# %%
X_train, X_test, Y_train, Y_test= train_test_split(dataset['data'], dataset['target'], random_state= 0)
dataFrame1=pd.DataFrame(X_test,columns=dataset.feature_names)
dataFrame1.describe(include='all')
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count          38.000000         38.000000          38.000000
# mean            5.715789          3.060526           3.647368
# std             0.679239          0.431552           1.671015
# min             4.400000          2.200000           1.000000
# 25%             5.125000          2.800000           1.625000
# 50%             5.750000          2.950000           4.450000
# 75%             6.175000          3.375000           4.800000
# max             7.300000          4.200000           6.300000
#
#        petal width (cm)
# count         38.000000
# mean           1.128947
# std            0.707836
# min            0.100000
# 25%            0.325000
# 50%            1.350000
# 75%            1.500000
# max            2.500000

# %% [markdown]
# ##### for random state value is 10

# %%
X_train, X_test, Y_train, Y_test= train_test_split(dataset['data'], dataset['target'], random_state= 10)
dataFrame1=pd.DataFrame(X_train,columns=dataset.feature_names)
dataFrame1.describe(include='all')
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         112.000000        112.000000         112.000000
# mean            5.840179          3.075000           3.716071
# std             0.839397          0.441231           1.794162
# min             4.300000          2.200000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.750000          3.000000           4.200000
# 75%             6.400000          3.400000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        112.000000
# mean           1.187500
# std            0.774611
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
X_train, X_test, Y_train, Y_test= train_test_split(dataset['data'], dataset['target'], random_state= 10)
dataFrame1=pd.DataFrame(X_test,columns=dataset.feature_names)
dataFrame1.describe(include='all')
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count          38.000000         38.000000          38.000000
# mean            5.852632          2.992105           3.884211
# std             0.804627          0.409602           1.690598
# min             4.400000          2.000000           1.200000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.450000
# 75%             6.375000          3.200000           5.075000
# max             7.700000          3.800000           6.700000
#
#        petal width (cm)
# count         38.000000
# mean           1.231579
# std            0.737456
# min            0.200000
# 25%            0.325000
# 50%            1.300000
# 75%            1.875000
# max            2.400000

# %% [markdown]
# ##### for random state value is 253

# %%
X_train, X_test, Y_train, Y_test= train_test_split(dataset['data'], dataset['target'], random_state= 255)
dataFrame1=pd.DataFrame(X_train,columns=dataset.feature_names)
dataFrame1.describe(include='all')
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         112.000000        112.000000         112.000000
# mean            5.842857          3.070536           3.759821
# std             0.820647          0.449752           1.775228
# min             4.300000          2.000000           1.000000
# 25%             5.175000          2.800000           1.600000
# 50%             5.750000          3.000000           4.400000
# 75%             6.400000          3.400000           5.100000
# max             7.700000          4.400000           6.900000
#
#        petal width (cm)
# count        112.000000
# mean           1.197321
# std            0.768696
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
X_train, X_test, Y_train, Y_test= train_test_split(dataset['data'], dataset['target'], random_state= 255)
dataFrame1=pd.DataFrame(X_test,columns=dataset.feature_names)
dataFrame1.describe(include='all')
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count          38.000000         38.000000          38.000000
# mean            5.844737          3.005263           3.755263
# std             0.860766          0.383404           1.755716
# min             4.400000          2.200000           1.300000
# 25%             5.025000          2.725000           1.500000
# 50%             5.800000          3.000000           4.200000
# 75%             6.375000          3.200000           5.000000
# max             7.900000          3.800000           6.600000
#
#        petal width (cm)
# count         38.000000
# mean           1.202632
# std            0.756767
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %% [markdown]
# ##### for random state value is 1000

# %%
X_train, X_test, Y_train, Y_test= train_test_split(dataset['data'], dataset['target'], random_state= 1000)
dataFrame1=pd.DataFrame(X_train,columns=dataset.feature_names)
dataFrame1.describe(include='all')
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         112.000000        112.000000         112.000000
# mean            5.861607          3.075000           3.747321
# std             0.866311          0.418384           1.823123
# min             4.300000          2.300000           1.000000
# 25%             5.100000          2.800000           1.500000
# 50%             5.800000          3.000000           4.400000
# 75%             6.500000          3.400000           5.100000
# max             7.900000          4.200000           6.900000
#
#        petal width (cm)
# count        112.000000
# mean           1.195536
# std            0.776152
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.825000
# max            2.500000

# %%
X_train, X_test, Y_train, Y_test= train_test_split(dataset['data'], dataset['target'], random_state= 1000)
dataFrame1=pd.DataFrame(X_test,columns=dataset.feature_names)
dataFrame1.describe(include='all')
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count          38.000000         38.000000          38.000000
# mean            5.789474          2.992105           3.792105
# std             0.711219          0.476123           1.601246
# min             4.400000          2.000000           1.300000
# 25%             5.100000          2.700000           1.900000
# 50%             5.800000          3.000000           4.250000
# 75%             6.375000          3.275000           4.975000
# max             7.200000          4.400000           6.000000
#
#        petal width (cm)
# count         38.000000
# mean           1.207895
# std            0.733515
# min            0.100000
# 25%            0.425000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %% [markdown]
# ##### for random state is 0 again

# %%
X_train, X_test, Y_train, Y_test= train_test_split(dataset['data'], dataset['target'], random_state= 0)
dataFrame1=pd.DataFrame(X_train,columns=dataset.feature_names)
dataFrame1.describe(include='all')
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         112.000000        112.000000         112.000000
# mean            5.886607          3.051786           3.796429
# std             0.871314          0.436196           1.800697
# min             4.300000          2.000000           1.100000
# 25%             5.100000          2.800000           1.575000
# 50%             5.800000          3.000000           4.250000
# 75%             6.500000          3.300000           5.200000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        112.000000
# mean           1.222321
# std            0.782662
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.900000
# max            2.500000

# %%
X_train, X_test, Y_train, Y_test= train_test_split(dataset['data'], dataset['target'], random_state= 0)
dataFrame1=pd.DataFrame(X_test,columns=dataset.feature_names)
dataFrame1.describe(include='all')
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count          38.000000         38.000000          38.000000
# mean            5.715789          3.060526           3.647368
# std             0.679239          0.431552           1.671015
# min             4.400000          2.200000           1.000000
# 25%             5.125000          2.800000           1.625000
# 50%             5.750000          2.950000           4.450000
# 75%             6.175000          3.375000           4.800000
# max             7.300000          4.200000           6.300000
#
#        petal width (cm)
# count         38.000000
# mean           1.128947
# std            0.707836
# min            0.100000
# 25%            0.325000
# 50%            1.350000
# 75%            1.500000
# max            2.500000

# %% [markdown]
# ##### for random state is 10 again

# %%
X_train, X_test, Y_train, Y_test= train_test_split(dataset['data'], dataset['target'], random_state= 10)
dataFrame1=pd.DataFrame(X_train,columns=dataset.feature_names)
dataFrame1.describe(include='all')
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         112.000000        112.000000         112.000000
# mean            5.840179          3.075000           3.716071
# std             0.839397          0.441231           1.794162
# min             4.300000          2.200000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.750000          3.000000           4.200000
# 75%             6.400000          3.400000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        112.000000
# mean           1.187500
# std            0.774611
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
X_train, X_test, Y_train, Y_test= train_test_split(dataset['data'], dataset['target'], random_state= 10)
dataFrame1=pd.DataFrame(X_test,columns=dataset.feature_names)
dataFrame1.describe(include='all')
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count          38.000000         38.000000          38.000000
# mean            5.852632          2.992105           3.884211
# std             0.804627          0.409602           1.690598
# min             4.400000          2.000000           1.200000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.450000
# 75%             6.375000          3.200000           5.075000
# max             7.700000          3.800000           6.700000
#
#        petal width (cm)
# count         38.000000
# mean           1.231579
# std            0.737456
# min            0.200000
# 25%            0.325000
# 50%            1.300000
# 75%            1.875000
# max            2.400000

# %% [markdown]
# ### Answer:
# 1. I report the descriptive statistic for every situation
# 2. If I don't specify random state, the result will never change when you use this model again
# 3.  reduce the deta order's factor on linear regression accuracy.

# %% [markdown]
# <h4> Problem #1-5. Optional (Extra Points) </h4>
#
#
# Write a python function that takes the dataset X  (matrix) and Y (numpy array) as an input and returns two non-overlapping datasets: the training and testing data, such that every entry to training set should be selected randomly. The proportion of the training and testing data should be 75%(training)/25%(test). Test your function using the synthetic dataset below.

# %%
import numpy as np 
import pandas as pd
X = np.stack((np.arange(100), 10*np.array(np.arange(100)),100*np.array(np.arange(100)),1000*np.array(np.arange(100))), axis=-1)
Y = np.random.randint(2, size=100)
df = pd.DataFrame(np.concatenate((X,Y[:,None]),axis=1), columns = ("X1","X2","X3","X4", "Y"))
df.head(10)
# Out:
#    X1  X2   X3    X4  Y
# 0   0   0    0     0  1
# 1   1  10  100  1000  1
# 2   2  20  200  2000  0
# 3   3  30  300  3000  0
# 4   4  40  400  4000  1
# 5   5  50  500  5000  0
# 6   6  60  600  6000  1
# 7   7  70  700  7000  1
# 8   8  80  800  8000  0
# 9   9  90  900  9000  1

# %%
#Write your narrative answer here
import random
def sel(df):
    train=df.sample(frac=0.8)
    print("train:\n",train)
    test=df.drop(train.index)
    print("\ntest:\n",test)
sel(df)
# Out:
# train:
#      X1   X2    X3     X4  Y
# 8    8   80   800   8000  0
# 62  62  620  6200  62000  1
# 69  69  690  6900  69000  0
# 3    3   30   300   3000  0
# 67  67  670  6700  67000  1
# 43  43  430  4300  43000  0
# 89  89  890  8900  89000  1
# 50  50  500  5000  50000  1
# 4    4   40   400   4000  1
# 7    7   70   700   7000  1
# 28  28  280  2800  28000  0
# 38  38  380  3800  38000  0
# 46  46  460  4600  46000  1
# 88  88  880  8800  88000  1
# 18  18  180  1800  18000  0
# 56  56  560  5600  56000  0
# 2    2   20   200   2000  0
# 86  86  860  8600  86000  1
# 29  29  290  2900  29000  1
# 75  75  750  7500  75000  1
# 40  40  400  4000  40000  1
# 44  44  440  4400  44000  0
# 52  52  520  5200  52000  1
# 96  96  960  9600  96000  1
# 27  27  270  2700  27000  1
# 34  34  340  3400  34000  1
# 63  63  630  6300  63000  0
# 91  91  910  9100  91000  1
# 20  20  200  2000  20000  1
# 47  47  470  4700  47000  0
# ..  ..  ...   ...    ... ..
# 36  36  360  3600  36000  1
# 30  30  300  3000  30000  1
# 13  13  130  1300  13000  0
# 12  12  120  1200  12000  0
# 79  79  790  7900  79000  0
# 71  71  710  7100  71000  1
# 31  31  310  3100  31000  0
# 1    1   10   100   1000  1
# 53  53  530  5300  53000  0
# 85  85  850  8500  85000  0
# 37  37  370  3700  37000  0
# 57  57  570  5700  57000  1
# 55  55  550  5500  55000  0
# 41  41  410  4100  41000  1
# 61  61  610  6100  61000  1
# 17  17  170  1700  17000  0
# 42  42  420  4200  42000  0
# 92  92  920  9200  92000  0
# 33  33  330  3300  33000  0
# 48  48  480  4800  48000  0
# 65  65  650  6500  65000  1
# 64  64  640  6400  64000  1
# 23  23  230  2300  23000  0
# 59  59  590  5900  59000  1
# 25  25  250  2500  25000  0
# 98  98  980  9800  98000  1
# 76  76  760  7600  76000  1
# 10  10  100  1000  10000  1
# 77  77  770  7700  77000  0
# 16  16  160  1600  16000  1
#
# [80 rows x 5 columns]
#
# test:
#      X1   X2    X3     X4  Y
# 0    0    0     0      0  1
# 5    5   50   500   5000  0
# 9    9   90   900   9000  1
# 11  11  110  1100  11000  1
# 15  15  150  1500  15000  1
# 26  26  260  2600  26000  1
# 32  32  320  3200  32000  0
# 51  51  510  5100  51000  0
# 66  66  660  6600  66000  1
# 68  68  680  6800  68000  0
# 70  70  700  7000  70000  0
# 73  73  730  7300  73000  1
# 74  74  740  7400  74000  1
# 78  78  780  7800  78000  0
# 80  80  800  8000  80000  1
# 84  84  840  8400  84000  1
# 87  87  870  8700  87000  1
# 93  93  930  9300  93000  0
# 94  94  940  9400  94000  0
# 95  95  950  9500  95000  0

# %% [markdown]
# <h3> Problem #2. Feature Selection  [10 points] </h3>  <br>
# In this part, you should download and analyze **"Boston House Prices" ** dataset **with only 4 features**. <br>
# (use code below to download  and change dataset)
#
# - Find the best two features using forward and backward selection to the Boston House Prices" dataset with only 4 features ('CHAS','RM','TAX', 'LSTAT'), use a linear regression model to find a best subset of features.
# - Comment your choice

# %%
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_boston
dataset = load_boston()
import numpy as np 
import pandas as pd
#print(dataset.keys())
# Data preprocessing
new_data= pd.DataFrame(dataset.data, columns=dataset.feature_names)[['CHAS','RM','TAX', 'LSTAT']]

X_train,X_test,Y_train,Y_test=train_test_split(new_data.values,dataset.target,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from pandas import read_csv
import statsmodels.formula.api as smf

model=smf.ols('dataset.target ~ CHAS+RM+TAX+LSTAT', new_data)
Fitting_results=model.fit()
print(Fitting_results.summary().tables[1])
print('p-values are: \n', Fitting_results.pvalues)

linreg=LinearRegression().fit(X_train, Y_train)
# Out:
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0779      3.090      0.025      0.980      -5.992       6.148
# CHAS           4.0769      0.946      4.310      0.000       2.219       5.935
# RM             5.0606      0.433     11.679      0.000       4.209       5.912
# TAX           -0.0064      0.002     -3.783      0.000      -0.010      -0.003
# LSTAT         -0.5543      0.048    -11.437      0.000      -0.649      -0.459
# ==============================================================================
# p-values are:
#  Intercept    9.798971e-01
# CHAS         1.961887e-05
# RM           4.885494e-28
# TAX          1.736692e-04
# LSTAT        4.495153e-27
# dtype: float64

# %% [markdown]
# for the backward, remove the largest p-value one: CHAS

# %%
model=smf.ols('dataset.target ~ RM+TAX+LSTAT', new_data)
Fitting_results=model.fit()
print(Fitting_results.summary().tables[1])
print('p-values are: \n', Fitting_results.pvalues)

linreg=LinearRegression().fit(X_train, Y_train)
# Out:
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.4987      3.140     -0.159      0.874      -6.668       5.671
# RM             5.1995      0.440     11.827      0.000       4.336       6.063
# TAX           -0.0065      0.002     -3.770      0.000      -0.010      -0.003
# LSTAT         -0.5526      0.049    -11.208      0.000      -0.649      -0.456
# ==============================================================================
# p-values are:
#  Intercept    8.738948e-01
# RM           1.212599e-28
# TAX          1.824338e-04
# LSTAT        3.574212e-26
# dtype: float64

# %% [markdown]
# then, remove the largest p-value exist: TAX

# %%
model=smf.ols('dataset.target ~ RM+LSTAT', new_data)
Fitting_results=model.fit()
print(Fitting_results.summary().tables[1])
print('p-values are: \n', Fitting_results.pvalues)

linreg=LinearRegression().fit(X_train, Y_train)
# Out:
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.3583      3.173     -0.428      0.669      -7.592       4.875
# RM             5.0948      0.444     11.463      0.000       4.222       5.968
# LSTAT         -0.6424      0.044    -14.689      0.000      -0.728      -0.556
# ==============================================================================
# p-values are:
#  Intercept    6.687649e-01
# RM           3.472258e-27
# LSTAT        6.669365e-41
# dtype: float64

# %% [markdown]
# for the forward selectoin:

# %%
CHAS_train = X_train[:,:1]
RM_train = X_train[:,1:2]
TAX_train = X_train[:,2:3]
LSTAT_train = X_train[:,3:]
CHAS_test = X_test[:,:1]
RM_test = X_test[:,1:2]
TAX_test = X_test[:,2:3]
LSTAT_test = X_test[:,3:]
regr1 = LinearRegression().fit(CHAS_train,Y_train)
regr2 = LinearRegression().fit(RM_train,Y_train)
regr3 = LinearRegression().fit(TAX_train,Y_train)
regr4 = LinearRegression().fit(LSTAT_train,Y_train)
print("R2 of regr1: ",regr1.score(CHAS_test,Y_test))
print("R2 of regr2: ",regr2.score(RM_test,Y_test))
print("R2 of regr3: ",regr3.score(TAX_test,Y_test))
print("R2 of regr4: ",regr4.score(LSTAT_test,Y_test))
# Out:
# R2 of regr1:  0.0489763879303
# R2 of regr2:  0.467900054314
# R2 of regr3:  0.0952371450838
# R2 of regr4:  0.457639361556

# %% [markdown]
# so, we choose the RM

# %%
regr21 = LinearRegression().fit(np.concatenate((RM_train,CHAS_train),axis=1),Y_train)
regr23 = LinearRegression().fit(np.concatenate((RM_train,TAX_train),axis=1),Y_train)
regr24 = LinearRegression().fit(np.concatenate((RM_train,LSTAT_train),axis=1),Y_train)
print("R2 of regr21: ",regr21.score(np.concatenate((RM_test,CHAS_test),axis=1),Y_test))
print("R2 of regr23: ",regr23.score(np.concatenate((RM_test,TAX_test),axis=1),Y_test))
print("R2 of regr24: ",regr24.score(np.concatenate((RM_test,LSTAT_test),axis=1),Y_test))
# Out:
# R2 of regr21:  0.489183148248
# R2 of regr23:  0.435203893137
# R2 of regr24:  0.569244541584

# %% [markdown]
# ### Answer:
# 1.for the backward selection, I choose CHAS first then choose TAX, because I choose the largest p value every time.
# 2.for the forward selection, I choose RM first, then choose LSTAT, because I choose the lowest RSS each time.

# %% [markdown]
# <h3>  Problem #3. Qualitative Variables  [10 points] </h3>
#
# In this part, you should download and analyze **"Boston House Prices"** dataset. <br>
# Use a code below to download the  dataset:

# %%
from sklearn.datasets import load_boston
dataset = load_boston()
print(dataset.keys())
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR'])

# %% [markdown]
# <h4> Problem #3-1. </h4> Follow steps to answer questions.
# > *Use train_test_split() with the option "random_state=0".
#
# - Identify qualitative feature in the dataset (a feature with dummy variable). What is an abbreviation for the qualitative feature? (What is a definition of that  abbreviation ?)
#
# - Fit a linear regression model with qualitative variable feature only. Report intercept and coefficient.
#
# - What can you infer about the qualitative feature from the coefficient? (Hint check lecture:  "Regression with Qualitative Features")

# %%
#Write your narrative answer here
print(dataset['DESCR'])
# Out:
# Boston House Prices dataset
# ===========================
#
# Notes
# ------
# Data Set Characteristics:
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive
#
#     :Median Value (attribute 14) is usually the target
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
#         - TAX      full-value property-tax rate per $10,000
#         - PTRATIO  pupil-teacher ratio by town
#         - B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#         - LSTAT    % lower status of the population
#         - MEDV     Median value of owner-occupied homes in $1000's
#
#     :Missing Attribute Values: None
#
#     :Creator: Harrison, D. and Rubinfeld, D.L.
#
# This is a copy of UCI ML housing dataset.
# http://archive.ics.uci.edu/ml/datasets/Housing
#
#
# This dataset was taken from the StatLib library which is maintained at Carnegie Mellon University.
#
# The Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic
# prices and the demand for clean air', J. Environ. Economics & Management,
# vol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics
# ...', Wiley, 1980.   N.B. Various transformations are used in the table on
# pages 244-261 of the latter.
#
# The Boston house-price data has been used in many machine learning papers that address regression
# problems.
#
# **References**
#
#    - Belsley, Kuh & Welsch, 'Regression diagnostics: Identifying Influential Data and Sources of Collinearity', Wiley, 1980. 244-261.
#    - Quinlan,R. (1993). Combining Instance-Based and Model-Based Learning. In Proceedings on the Tenth International Conference of Machine Learning, 236-243, University of Massachusetts, Amherst. Morgan Kaufmann.
#    - many more! (see http://archive.ics.uci.edu/ml/datasets/Housing)

# %%
dataFrame1=pd.DataFrame(dataset.data,columns=dataset.feature_names)
dataFrame1.describe(include='all')
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.593761   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.596783   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.647423   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT
# count  506.000000
# mean    12.653063
# std      7.141062
# min      1.730000
# 25%      6.950000
# 50%     11.360000
# 75%     16.955000
# max     37.970000

# %%
X=pd.DataFrame(dataset.data, columns=dataset.feature_names)[['CHAS']]
Y = dataset.target
X_train, X_test, Y_train, Y_test= train_test_split(X, Y, random_state= 0)

linreg= LinearRegression().fit(X_train, Y_train)
print("The intercept is: ", linreg.intercept_)
print("The coefficient of 'CHAS' feature is:",linreg.coef_)
# Out:
# The intercept is:  22.2274011299
# The coefficient of 'CHAS' feature is: [ 5.78059887]

# %%
import matplotlib.pyplot as plt
estimated_linearmodel= linreg.intercept_ + linreg.coef_ * X
plt.figure(figsize=(10,8))
plt.scatter(X, Y, marker= 'o') #plot data points
plt.plot(X, estimated_linearmodel, 'r-')
plt.xlabel('Feature value (X)'); plt.ylabel('Target value (Y)')
plt.show()

# %% [markdown]
# ### Answer:
# 1.CHAS(Charles River dummy variable)
# 2.intercept:22.4132911392       coefficient:6.00410017
# 3.we can linear regression with qualitative factor and we can't recognize the difference between qualitative factor and numeric factor by coefficients value.

# %% [markdown]
# <h3>  Problem #4. Regularization [30 points]  </h3>

# %% [markdown]
# <h4> Problem #4-1. </h4> Answer the following questions
#
# - What is the objective using regularization?
# - Do you need to use regularization if you have only 1 feature (B0 and B1)?

# %% [markdown]
# #Write your narrative answer here
# ### Answer:
# 1. solve the overfitting problem
# 2. no

# %% [markdown]
# <h4> Problem #4-2.Ridge Regression </h4>  <br>
# In this part, you should download and analyze **"Boston House Prices"** dataset. <br>
# Use a code below to download the  dataset:

# %%
dataset = load_boston()
print(dataset.keys())
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR'])

# %% [markdown]
# Follow steps to answer questions.
# - Fit a linear regression model with all features and report the estimated coefficients for the fitted model (do not just print summary, make a table with feature names and estimated coefficients)
# -  Fit a ridge regression model with λ = 1. Report the estimated coefficients for the fitted model.
# -  Fit a ridge regression model with λ = 0. Report the estimated coefficients for the fitted model.
# - Compare estimated coefficients of ridge regression models with λ = 1 and λ = 0  and linear regression model. (you can use descriptive statistics)
# - What did you observe from this comparison?
# - Comment your observation.

# %%
#Write your narrative answer here
df = (pd.DataFrame(dataset.data, columns= dataset.feature_names))
df['target'] = dataset.target
Xall = df[['target','RM','LSTAT','CRIM','ZN','INDUS','CHAS','NOX','AGE','DIS','RAD','TAX','PTRATIO','B']]

model=smf.ols('target ~ RM+LSTAT+CRIM+ZN+INDUS+CHAS+NOX+AGE+DIS+RAD+TAX+PTRATIO+B', Xall)
Fitting_results=model.fit()
print(Fitting_results.summary().tables[1])

X=dataset.data
Y = dataset.target
X_train, X_test, Y_train, Y_test= train_test_split(X, Y, random_state= 0)

linreg= LinearRegression().fit(X_train, Y_train)
##print("The intercept is: ", linreg.intercept_)
##print("The coefficient of 'CHAS' feature is:",linr)
dataFrame1=pd.DataFrame(linreg.coef_,dataset.feature_names, columns=['value'])
data
print('estimated coefficients:\n')
print(dataFrame1)
# Out:
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     36.4911      5.104      7.149      0.000      26.462      46.520
# RM             3.8048      0.418      9.102      0.000       2.983       4.626
# LSTAT         -0.5255      0.051    -10.366      0.000      -0.625      -0.426
# CRIM          -0.1072      0.033     -3.276      0.001      -0.171      -0.043
# ZN             0.0464      0.014      3.380      0.001       0.019       0.073
# INDUS          0.0209      0.061      0.339      0.735      -0.100       0.142
# CHAS           2.6886      0.862      3.120      0.002       0.996       4.381
# NOX          -17.7958      3.821     -4.658      0.000     -25.302     -10.289
# AGE            0.0008      0.013      0.057      0.955      -0.025       0.027
# DIS           -1.4758      0.199     -7.398      0.000      -1.868      -1.084
# RAD            0.3057      0.066      4.608      0.000       0.175       0.436
# TAX           -0.0123      0.004     -3.278      0.001      -0.020      -0.005
# PTRATIO       -0.9535      0.131     -7.287      0.000      -1.211      -0.696
# B              0.0094      0.003      3.500      0.001       0.004       0.015
# ==============================================================================
# estimated coefficients:
#
#              value
# CRIM     -0.116870
# ZN        0.043994
# INDUS    -0.005348
# CHAS      2.394554
# NOX     -15.629837
# RM        3.761455
# AGE      -0.006950
# DIS      -1.435205
# RAD       0.239756
# TAX      -0.011294
# PTRATIO  -0.986626
# B         0.008557
# LSTAT    -0.500029

# %%
from sklearn.linear_model import Ridge
# train and fit the ridge regression model with training data
RidgeModel=Ridge( ).fit(X_train, Y_train) # this uses default alpha of 1
#find the R2 metric with the .score
RidgeModel.score(X_test,Y_test)
np.sum(RidgeModel.coef_==0)
# Out:
# 0

# %%
dataFrame1=pd.DataFrame(RidgeModel.coef_,dataset.feature_names, columns=['value'])
print('estimated coefficients:\n')
print(dataFrame1)
# Out:
# estimated coefficients:
#
#             value
# CRIM    -0.113745
# ZN       0.045392
# INDUS   -0.035052
# CHAS     2.304663
# NOX     -8.147359
# RM       3.799228
# AGE     -0.014216
# DIS     -1.336809
# RAD      0.216264
# TAX     -0.011752
# PTRATIO -0.904760
# B        0.008923
# LSTAT   -0.508385

# %%
from sklearn.linear_model import Ridge
# train and fit the ridge regression model with training data
RidgeModel=Ridge(alpha=0).fit(X_train, Y_train) # this uses default alpha of 0
#find the R2 metric with the .score
RidgeModel.score(X_test,Y_test)
np.sum(RidgeModel.coef_==0)
# Out:
# 0

# %%
dataFrame1=pd.DataFrame(RidgeModel.coef_,dataset.feature_names, columns=['value'])
print('estimated coefficients:\n')
print(dataFrame1)
# Out:
# estimated coefficients:
#
#              value
# CRIM     -0.116870
# ZN        0.043994
# INDUS    -0.005348
# CHAS      2.394554
# NOX     -15.629837
# RM        3.761455
# AGE      -0.006950
# DIS      -1.435205
# RAD       0.239756
# TAX      -0.011294
# PTRATIO  -0.986626
# B         0.008557
# LSTAT    -0.500029

# %% [markdown]
# ### Answer:
#
# Compare estimated coefficients of ridge regression models with λ = 1 and λ = 0 and linear regression model, they are simiar, but with larger alpha, results are stronger
# And when alpha equals to zero, it is the same as the ols linear regression.

# %% [markdown]
# <h4> Problem #4-3.Ridge Regression (part 2) </h4>  <br>
# Fit a ridge regression with λ = 5, 10, 50, 100, and 1000. For each value, report the estimated coefficients for the fitted model (do not just print summary, make a DataFrame with feature names and estimated coefficients)
# - What happens to the coefficients as you increase λ?
# - What happens to the flexibility of the model as you increase λ?

# %%
#Write your narrative answer here
alpha=[5,10,50,100,1000]
for x in alpha:
    RidgeModel=Ridge(alpha=x).fit(X_train, Y_train) # this uses default alpha of x
    dataFrame1=pd.DataFrame(RidgeModel.coef_,dataset.feature_names, columns=['value'])
    print('estimated coefficients when alpha=',x,':')
    print(dataFrame1)
    print('\n')
# Out:
# estimated coefficients when alpha= 5 :
#             value
# CRIM    -0.111712
# ZN       0.046949
# INDUS   -0.055871
# CHAS     1.982748
# NOX     -2.802456
# RM       3.706435
# AGE     -0.018374
# DIS     -1.268301
# RAD      0.204486
# TAX     -0.012292
# PTRATIO -0.853248
# B        0.009170
# LSTAT   -0.523201
#
#
# estimated coefficients when alpha= 10 :
#             value
# CRIM    -0.111268
# ZN       0.047930
# INDUS   -0.060710
# CHAS     1.687262
# NOX     -1.543206
# RM       3.549560
# AGE     -0.018206
# DIS     -1.252946
# RAD      0.206644
# TAX     -0.012622
# PTRATIO -0.847922
# B        0.009193
# LSTAT   -0.536472
#
#
# estimated coefficients when alpha= 50 :
#             value
# CRIM    -0.108919
# ZN       0.051976
# INDUS   -0.067184
# CHAS     0.785963
# NOX     -0.334039
# RM       2.616806
# AGE     -0.010997
# DIS     -1.214426
# RAD      0.230319
# TAX     -0.013786
# PTRATIO -0.869840
# B        0.008829
# LSTAT   -0.604153
#
#
# estimated coefficients when alpha= 100 :
#             value
# CRIM    -0.105931
# ZN       0.053887
# INDUS   -0.067772
# CHAS     0.481930
# NOX     -0.163467
# RM       1.982008
# AGE     -0.004330
# DIS     -1.154603
# RAD      0.244168
# TAX     -0.014375
# PTRATIO -0.879572
# B        0.008457
# LSTAT   -0.648463
#
#
# estimated coefficients when alpha= 1000 :
#             value
# CRIM    -0.086351
# ZN       0.054640
# INDUS   -0.047192
# CHAS     0.073313
# NOX     -0.006844
# RM       0.441204
# AGE      0.026831
# DIS     -0.548033
# RAD      0.231527
# TAX     -0.015109
# PTRATIO -0.650367
# B        0.007257
# LSTAT   -0.729129

# %% [markdown]
# ### Answer:
# When alpha increase, coefficients keep getting close to 0, the flexibility is decreasing, the model is more closer to linear model.

# %% [markdown]
# <h4> Problem #4-4 Lasso Regression </h4>  <br>
# In this part, you should download and analyze **"Boston House Prices"** dataset. <br>

# %% [markdown]
# Follow steps to answer questions.
# - Fit a linear regression model with all features and report the estimated coefficients for the fitted model (do not just print summary, make a DataFrame with feature names and estimated coefficients)
# -  Fit a lasso regression model with λ = 1. Report the estimated coefficients for the fitted model.
# -  Fit a lasso regression model with λ = 0. Report the estimated coefficients for the fitted model.
# - Compare estimated coefficients of lasso regression models with λ = 1 and λ = 0, ridge regression models with λ = 1 and λ = 0 and linear regression model. (you can use descriptive statistics)
#
# - What did you observe from this comparison?
#
# - Comment your observation.

# %%
#Write your narrative answer here
X=dataset.data
Y = dataset.target
X_train, X_test, Y_train, Y_test= train_test_split(X, Y, random_state= 0)

linreg= LinearRegression().fit(X_train, Y_train)
##print("The intercept is: ", linreg.intercept_)
##print("The coefficient of 'CHAS' feature is:",linr)
lindf=pd.DataFrame(linreg.coef_,dataset.feature_names, columns=['value'])
print('estimated coefficients:\n')
print(lindf)
# Out:
# estimated coefficients:
#
#              value
# CRIM     -0.116870
# ZN        0.043994
# INDUS    -0.005348
# CHAS      2.394554
# NOX     -15.629837
# RM        3.761455
# AGE      -0.006950
# DIS      -1.435205
# RAD       0.239756
# TAX      -0.011294
# PTRATIO  -0.986626
# B         0.008557
# LSTAT    -0.500029

# %%
from sklearn.linear_model import Lasso
lassoModel=Lasso( ).fit(X_train, Y_train)
np.sum(lassoModel.coef_==0)
# Out:
# 2

# %%
l1df=pd.DataFrame(lassoModel.coef_,dataset.feature_names, columns=['value'])
print('estimated coefficients:\n')
print(l1df)
# Out:
# estimated coefficients:
#
#             value
# CRIM    -0.059218
# ZN       0.050014
# INDUS   -0.001553
# CHAS     0.000000
# NOX     -0.000000
# RM       0.758533
# AGE      0.013051
# DIS     -0.710499
# RAD      0.195772
# TAX     -0.014148
# PTRATIO -0.805582
# B        0.007156
# LSTAT   -0.742312

# %%
lassoModel00=Lasso(alpha=0).fit(X_train, Y_train)
np.sum(lassoModel00.coef_==0)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:477: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# 0

# %%
l0df=pd.DataFrame(lassoModel00.coef_,dataset.feature_names, columns=['value'])
print('estimated coefficients:\n')
print(l0df)
# Out:
# estimated coefficients:
#
#              value
# CRIM     -0.116870
# ZN        0.043994
# INDUS    -0.005348
# CHAS      2.394554
# NOX     -15.629837
# RM        3.761455
# AGE      -0.006950
# DIS      -1.435205
# RAD       0.239756
# TAX      -0.011294
# PTRATIO  -0.986626
# B         0.008557
# LSTAT    -0.500029

# %%
print('for linear:')
print(lindf.describe(include='all'),'\n')
print('for alpha=1:')
print(lindf.describe(include='all'),'\n')
print('for alpha=0:')
print(lindf.describe(include='all'))
# Out:
# for linear:
#            value
# count  13.000000
# mean   -0.941834
# std     4.618795
# min   -15.629837
# 25%    -0.500029
# 50%    -0.006950
# 75%     0.043994
# max     3.761455
#
# for alpha=1:
#            value
# count  13.000000
# mean   -0.941834
# std     4.618795
# min   -15.629837
# 25%    -0.500029
# 50%    -0.006950
# 75%     0.043994
# max     3.761455
#
# for alpha=0:
#            value
# count  13.000000
# mean   -0.941834
# std     4.618795
# min   -15.629837
# 25%    -0.500029
# 50%    -0.006950
# 75%     0.043994
# max     3.761455

# %% [markdown]
# ### Answer:
# When alpha = 1.0, 11 weights of features becomes 0, which means regularization works, while with alpha = 0.0, it results in same result without regularization.

# %% [markdown]
# <h4> Problem #4-5.Lasso Regression (part 2) </h4>  <br>
# Fit a lasso regression with λ = 5, 10, 50, 100, and 1000. For each value, report the estimated coefficients for the fitted model (do not just print summary, make a DataFrmae with feature names and estimated coefficients)
# - What happens to the coefficients as you increase λ?
# - What happens to the flexibility of the model as you increase λ?

# %%
#Write your narrative answer here
for x in alpha:
    lassoModel=Lasso(alpha=x).fit(X_train, Y_train) # this uses default alpha of x
    dataFrame1=pd.DataFrame(lassoModel.coef_,dataset.feature_names, columns=['value'])
    print('estimated coefficients when alpha=',x,':')
    print(dataFrame1)
    print('\n')
# Out:
# estimated coefficients when alpha= 5 :
#             value
# CRIM    -0.000000
# ZN       0.043374
# INDUS   -0.000000
# CHAS     0.000000
# NOX      0.000000
# RM       0.000000
# AGE      0.029813
# DIS     -0.000000
# RAD      0.000000
# TAX     -0.010010
# PTRATIO -0.000000
# B        0.004907
# LSTAT   -0.732126
#
#
# estimated coefficients when alpha= 10 :
#             value
# CRIM    -0.000000
# ZN       0.032687
# INDUS   -0.000000
# CHAS     0.000000
# NOX      0.000000
# RM       0.000000
# AGE      0.000000
# DIS     -0.000000
# RAD      0.000000
# TAX     -0.011559
# PTRATIO -0.000000
# B        0.006793
# LSTAT   -0.549712
#
#
# estimated coefficients when alpha= 50 :
#             value
# CRIM    -0.000000
# ZN       0.003385
# INDUS   -0.000000
# CHAS     0.000000
# NOX     -0.000000
# RM       0.000000
# AGE     -0.000000
# DIS      0.000000
# RAD      0.000000
# TAX     -0.023138
# PTRATIO -0.000000
# B        0.010789
# LSTAT   -0.000000
#
#
# estimated coefficients when alpha= 100 :
#             value
# CRIM    -0.000000
# ZN       0.000000
# INDUS   -0.000000
# CHAS     0.000000
# NOX     -0.000000
# RM       0.000000
# AGE     -0.000000
# DIS      0.000000
# RAD     -0.000000
# TAX     -0.022912
# PTRATIO -0.000000
# B        0.004822
# LSTAT   -0.000000
#
#
# estimated coefficients when alpha= 1000 :
#          value
# CRIM      -0.0
# ZN         0.0
# INDUS     -0.0
# CHAS       0.0
# NOX       -0.0
# RM         0.0
# AGE       -0.0
# DIS        0.0
# RAD       -0.0
# TAX       -0.0
# PTRATIO   -0.0
# B          0.0
# LSTAT     -0.0

# %% [markdown]
# ### Answer:
# with the increase of alpha, the coefficients shrink to zero. the model is getting close to linear model. And the flexibility will be low.

# %% [markdown]
# <h3>  Problem #5.Logistic Regression [30 points] </h3>

# %% [markdown]
# <h4> Problem #5-1. </h4>  <br>
# We fit a logistic regression model to predict the probability that an individual will default on his/her credit card balance. We used the total balance (single feature) to fit the model and got the results shown in the table below.

# %% [markdown]
# |        |Coefficient| Std.error|Z -statistic|P-Value|
# |:--:|:-------------------------------:|
# |Intercept|-10.6513|0.3612|-29.5|<0.0001|
# |balance|0.0055|0.002|24.9|<0.0001|

# %% [markdown]
# - What is the parametric model used in logistic regression?
# - What is the probability that an individual with a balance equal to 15000 dollar will default?
# - What is the probability that an individual with balance equals to 800 dollar will not default?

# %% [markdown]
# #Write your narrative answer here
# ### Answer:
# 1. Linear regrassion is used in this problem
# 2. 1
# 3. 0.9981

# %% [markdown]
# <h4> Problem #5-2. </h4>  <br>
#
# The coefficients of logistic regression are obtained by maximizing the likelihood function
#
# \begin{array} \\
# l(\beta) = \prod_{i:y_{i}=1} P(y_{i} = 1|x)\prod_{i{}':y_{{i}'}=0} (1-P(y_{{i}'} = 1|x))
# \end{array}
# Show that maximizing the
# likelihood function is equivalent to minimizing the cost function $J(\beta)$, such that.
# \begin{array} \\
# J(\beta) = -\sum [y_{i} log(P(y_{i} = 1|x)) + (1- y_{i})log(1- P(y_{i} = 1|x))]
# \end{array}
#
#
# Here $n$ is the number training examples. Mention one possible method for obtaining the
# optimal coefficients.

# %% [markdown]
# ### Answer:
# batch gradient descent
