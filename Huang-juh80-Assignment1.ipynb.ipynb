# %% [markdown]
# <div style="text-align: center;">
# <h2>INFSCI 2915 Foundations- Machine Learning - Spring 2018 </h2>
# <h1 style="font-size: 250%;">Assignment #1</h1>
# <h3>Issued Tuesday, 2/06/2018; Due Tuesday, 11:59pm, 2/13/2018</h3>
# <h3>Total points: 100 </h3>
# </div>

# %%
# Type in your information in the double quotes
firstName = "Junxi"
lastName = "Huang"
pittID = "juh80"

# %% [markdown]
# ---

# %% [markdown]
# <h3>  Problem #1. K-nearest neighbors  [20 points] </h3>
#
# The table below provides a training data set containing six observations, three predictors, and one qualitative response variable.
# Suppose we wish to use this data set to make a prediction for Y when X1 = X2 = X3 = 0 using K-nearest neighbors.

# %% [markdown]
# |Obs.|X1|X2|X3|Y
# |--|-------------------------------|
# |1 |0|3|0|Green|
# |2 |2|0|0|Green|
# |3|0|1|3|Green|
# |4|0|1|2|Red|
# |5|-1|0|1|Red|
# |6|1|1|1|Green|

# %% [markdown]
# <b>Problem #1-1.</b> Compute the Euclidean distance between each observation and the test point, X1 = X2 = X3 = 0

# %%
#Write your narrative answer here
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier 
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import preprocessing


a=np.array([[0,3,0],[2.0,0],[0,1,3],[0,1,2],[-1,0,1],[1,1,1]])
b=np.array([[0],[0],[0],[1],[1],[0]])
##X_train, X_test, Y_train, Y_test = train_test_split(a,b,random_state=6)

def eucldist_forloop(coords1, coords2):
    """ Calculates the euclidean distance between 2 lists of coordinates. """
    dist = 0
    for (x, y) in zip(coords1, coords2):
        dist += (x - y)**2
    return dist**0.5

s=np.array([0,0,0])
for num in range(0,6):
   
    dis=eucldist_forloop(a[num],s)
    print("Obs",num+1,"=",dis)
# Out:
# Obs 1 = 3.0
# Obs 2 = 2.0
# Obs 3 = 3.16227766017
# Obs 4 = 2.2360679775
# Obs 5 = 1.41421356237
# Obs 6 = 1.73205080757

# %% [markdown]
# <b>Problem #1-2.</b> What is our prediction with K = 1? and explain why.

# %% [markdown]
# <p>red</p>
#
# <p>Because you find the nearest point(depend on Euclidean distance) with the test point(X1=X2=X3=0)
# And th e nearest point is Obs5, which color is red.</p>

# %% [markdown]
# <b>Problem #1-3.</b> What is our prediction with K = 3? and explain why.

# %% [markdown]
# <p>Green</p>
# Because you find 3 nearest(depend on Euclidean distance) points with the test point(X1=X2=X3=0)
# And the nearest points(depend on Euclidean distance) are Obs2, Obs5 and Obs6, which color are green, red and green.
# So the prediction will be green.

# %% [markdown]
# <b>Problem #1-4.</b>  How using a different number of K has an impact on the performance? explain.

# %% [markdown]
# different K means the number of the decide points, our prediction is dpended by the decide points, which color point is more.

# %% [markdown]
# ---

# %% [markdown]
# <h3>  Problem #2. Answer those questions about linear regression [30 points] </h3>
# - Writing a code is not required for this question<br>
# - Feel free to select any type of submission you are comfortable with (Since it may require some mathematical formula and symbols; MS Word, or scanned version of your writing will be fine)

# %% [markdown]
# <b>Problem #2-1.</b> Find the least squared fit of a linear regression model using the following traning data

# %% [markdown]
# |Smoke index(x)|Lung cancer mortality index(y)|
# |:--:|:-------------------------------:|
# |127|115|
# |121|128|
# |94|128|
# |126|156|
# |102|101|
# |111|128|
# |95|115|
# |89|105|
# |101|87|

# %% [markdown]
# #Write your narrative answer here
#
# see word

# %% [markdown]
# <b>Problem #2-2.</b> Given the test data below, compute the R-squared metric of the fitted model

# %% [markdown]
# |Xi|Yi|
# |:--:|:-------------------------------:|
# |90|103|
# |106|131|
# |105|85|
# |115|99|
# |113|144|

# %%
#Write your narrative answer here
XP:      105
yP:      112
RSS:  4.455353756701787  TSS:  81.0  yi:  105.11077089157061
RSS:  192.86634204731027  TSS:  361.0  yi:  117.11236729866064
RSS:  983.5918241978638  TSS:  729.0  yi:  116.36226752321751
RSS:  618.1819602667362  TSS:  169.0  yi:  123.8632652776488
RSS:  468.15692474439777  TSS:  1024.0  yi:  122.36306572676254
RSS: 2267.2524050130096    TSS: 2364.0
R2: 0.04092537859009746

# %% [markdown]
# ---

# %% [markdown]
# <h3>  Problem #3. This question involves the use of multiple linear regression on the Boston dataset [30 points]</h3> <br>
# In this part, you should download and analyze **"Boston House Prices"** dataset. <br>
# Here use a code below to download the  dataset:

# %%
from sklearn.datasets import load_boston
import pandas as pd
import numpy as np
dataset = load_boston()
print(dataset.keys())
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR'])

# %% [markdown]
# <b>Problem #3-1</b> Print the description of the dataset.
#
# <b> Answer the following question:</b>
#
# - Whole dataset contains 14 attributes, (13 numeric/categorical predictive and 1 target value)  what is a abbreviation of the target value?

# %%
#Write your narrative answer here
print(dataset.DESCR)
# Out:
# Boston House Prices dataset
# ===========================
#
# Notes
# ------
# Data Set Characteristics:
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive
#
#     :Median Value (attribute 14) is usually the target
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
#         - TAX      full-value property-tax rate per $10,000
#         - PTRATIO  pupil-teacher ratio by town
#         - B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#         - LSTAT    % lower status of the population
#         - MEDV     Median value of owner-occupied homes in $1000's
#
#     :Missing Attribute Values: None
#
#     :Creator: Harrison, D. and Rubinfeld, D.L.
#
# This is a copy of UCI ML housing dataset.
# http://archive.ics.uci.edu/ml/datasets/Housing
#
#
# This dataset was taken from the StatLib library which is maintained at Carnegie Mellon University.
#
# The Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic
# prices and the demand for clean air', J. Environ. Economics & Management,
# vol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics
# ...', Wiley, 1980.   N.B. Various transformations are used in the table on
# pages 244-261 of the latter.
#
# The Boston house-price data has been used in many machine learning papers that address regression
# problems.
#
# **References**
#
#    - Belsley, Kuh & Welsch, 'Regression diagnostics: Identifying Influential Data and Sources of Collinearity', Wiley, 1980. 244-261.
#    - Quinlan,R. (1993). Combining Instance-Based and Model-Based Learning. In Proceedings on the Tenth International Conference of Machine Learning, 236-243, University of Massachusetts, Amherst. Morgan Kaufmann.
#    - many more! (see http://archive.ics.uci.edu/ml/datasets/Housing)

# %% [markdown]
# MEDV is the target value

# %% [markdown]
# <b>Problem #3-2 </b> Generate descriptive statistics using DataFrame. (hint: use "DataFrame . describe" function)<br>
#
# Follow two steps to answer questions.
# - Create a DataFrame usnig "data" from the dataset with columns using "feature_names".
# - Generate descriptive statistics
#
# <b> Answer the following questions:</b>
#
# -  Which feature has the highest range (minimum and maximum value)?
#
# -  Which feature has the lowest mean?
#
# -  Which feature has a lowest standard deviation?

# %%
#Write your narrative answer here
dataFrame1=pd.DataFrame(dataset.data,columns=dataset.feature_names)
dataFrame1.describe(include='all')
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.593761   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.596783   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.647423   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT
# count  506.000000
# mean    12.653063
# std      7.141062
# min      1.730000
# 25%      6.950000
# 50%     11.360000
# 75%     16.955000
# max     37.970000

# %% [markdown]
# 1. TAX has the highest range(min:187, high:711)
# 2. CHAS has the lowest mean(0.069170)
# 3. NOXhas the lowest standard mean(0.115878)

# %% [markdown]
# <b>Problem #3-3 </b> Feature Scaling
#
# <b> Answer the following questions:</b>
#
# - From the information above, Do you recommend **feature scaling** to improve performance? Explain.
#
# - What is a difference between MinMaxScaler and StandardScaler?

# %% [markdown]
# #Write your narrative answer here
# 1. Yes, I will recommand scalling the feature, beacause the data range from 0 to 711 is too big for this data site. And the std and mean also vary in big scope, scalling the data will help us to analyse these data.
# 2. MinMaxScaler: scales features to be in range 0 -1, StandardScaler: scales features so that they are all with zero mean and unit variance

# %% [markdown]
# <b>Problem #3-4 </b> Calculate and report **correlations** between features and the target
#
# <b> Answer the following questions:</b>
#
# - What is a difference between positive and negative numbers on the correlation table? Explain.
# - What is the lowest number in the table? Do you think it is the most or the least helpful features in predicting the
# target class? Explain.

# %% [markdown]
# #Write your narrative answer here
# 1) Positive numbers mean that the features, when compared against each other, are correlated and have an positive impact. Higher positive numbers mean that any affect on one of the feature have direct impact on the correlated feature. For example, the features price and demand quantity would be positively correlated. As the demand quantity for a product increases, it has a direct impact on the price of the product and it would raise the price resulting in an upward sloping curve. Negative numbers are the exact opposite and show an inverse relation between features. If the negative number is greater on the correlation table, it means that the features are negatively affected by actions of other features. For example, if a house is located in a flooding zone, the price will be negatively affected by the location. The numbers closer to zero show no or very little correlation between the features.
#
# 2) The lowest number in the table is -1. It is not very important in the fact that it shows inverse relations between the features. We could analyze the data and see that if a feature that impacts the target directly is negatively correlated with another feature, we could discard the feature. We could also analyze to see if a feature does not affect the target and has high negative correlation with other features to see if the other features have affect on the target.

# %% [markdown]
# <b>Problem #3-5 </b>
# Follow two steps to answer questions.
#
# - Add 1 more column (dataset.target) to your DataFrame (give a name).
#
# - Find the correlation matrix that shows the correlation between each pair of features. <br>
#
# - Plot a correlation matrix<br> You can use the code below or write your own code to plot a correlation matrix *(extra point for writing your own code)*
#
#  <b>Answer the following questions:</b>
#
# - What is the correlation between the feature RM and the LSTAT?
# - What does this value of correlation indicate?
# - Can you detect most or the least helpful features in predicting the target class from correlation matrix or from plot? How?

# %%
# %matplotlib notebook
from sklearn.datasets import load_boston
dataset = load_boston()
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
sns.set(style="white")
# Get correlation matrix
df = (pd.DataFrame(dataset.data, columns= dataset.feature_names))
df['target'] = dataset.target
corr = df.corr()
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))
# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1, center=0, square=True, linewidths=.9, cbar_kws={"shrink": .7})
# Out:
# <img src="data:image/png;base64,..." width="1100">

# %% [markdown]
# #Write your narrative answer here
# 1) RM and LSTAT have a negative correlation： -0.6.
#
# 2) The Negative value will make a decrease in value in LSTAT and vice versa.
#
# 3)

# %% [markdown]
# <b>Problem #3-6 </b> Scatter plot. <br>
#
# Follow three steps to answer questions <br>
# - Plot LSTAT versus target variable
# - Plot RM versus target variable
# - Plot CHAS versus target variable <br>
#
# <b> Answer the following questions:</b>
# - Is the relationship linear?
# - Which looks the most nonlinear? Explain your chouce

# %%
#Write your narrative answer here
import matplotlib.pyplot as plt
from pandas import read_csv
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import numpy 
from sklearn.metrics import r2_score

plt.figure(figsize=(10,10))
plt.scatter(df['LSTAT'],df['target'])

plt.xlabel('LSTAT')
plt.ylabel('target')
plt.title(" LSTAT versus target")

X1=df.LSTAT.values.reshape(-1,1) # define features: horsepower 
Y1=df.target.values.reshape(-1,1) # define label: miles per gallon

model=LinearRegression()
fitted_model=model.fit(X1,Y1)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# This is linear

# %%
plt.figure(figsize=(10,10))
plt.scatter(df['RM'],df['target'])
plt.xlabel('RM')
plt.ylabel('target')
plt.title("RM versus target")
# Out:
# <img src="data:image/png;base64,..." width="1000">
# Text(0.5,1,'RM versus target')

# %%
This is linear

# %%
plt.figure(figsize=(10,10))
plt.scatter(df['CHAS'],df['target'])
plt.xlabel('CHAS')
plt.ylabel('target')
plt.title("CHAS versus target")
# Out:
# <img src="data:image/png;base64,..." width="1000">
# Text(0.5,1,'CHAS versus target')

# %% [markdown]
# This is not linear

# %% [markdown]
# CHAS versus target is the worst, because the correlation between them are not linear.

# %% [markdown]
# <b>Problem #3-7.</b> Follow steps to answer questions.
# > *Use train_test_split() with the option "random_state=0".
#
# 1. Fit a linear regression model with RM and LSTAT features only. Find the R-squared metric.
# 2. Fit a linear regression model using RM, LSTAT and include the interaction term (RM * LSTAT). How R-squared metric differs from the previous model without interaction term?
# 3. Fit a linear regression model using LSTAT and include the polynomial term ( $LSTAT^2$).  Find the R-squared metric.
# 4. Fit linear regression model using LSTAT and include the polynomial term ( $LSTAT^2$ and $LSTAT^3$ ). Find the R-squared metric.
# - How does R-squared metric differ in the previous models ? <br> Comment your observation.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
X = df[['RM','LSTAT']]
Y = dataset.target

X_train, X_test, Y_train, Y_test= train_test_split(X, Y, random_state= 0)

linreg= LinearRegression()
linreg.fit(X_train, Y_train)
print("The R Square Metric using only RM and LSTAT features: ",linreg.score(X_test,Y_test))

X1 = df['RM']*df['LSTAT']
X2 = df['RM']
X3 = df['LSTAT']
X = pd.concat([X2,X3,X1],axis=1)
X_train, X_test, Y_train, Y_test= train_test_split(X, Y, random_state= 0)
linreg.fit(X_train, Y_train)
print('\n')
print("The R Square Metric using RM, LSTAT, and interaction term(RM*LSTAT) features: ",linreg.score(X_test,Y_test))

X = pd.concat([X3,X3**2],axis=1)
X_train, X_test, Y_train, Y_test= train_test_split(X, Y, random_state= 0)
linreg.fit(X_train, Y_train)
print('\n')
print("The R Square Metric using LSTAT and polynomial term(LSTAT*LSTAT) features: ",linreg.score(X_test,Y_test))

X = pd.concat([X3,X3**2,X3**3],axis=1)
X_train, X_test, Y_train, Y_test= train_test_split(X, Y, random_state= 0)
linreg.fit(X_train, Y_train)
print('\n')
print("The R Square Metric using LSTAT and polynomial term(LSTAT^2 and LSTAT^3) features: ",linreg.score(X_test,Y_test))
# Out:
# The R Square Metric using only RM and LSTAT features:  0.569244541584
#
#
# The R Square Metric using RM, LSTAT, and interaction term(RM*LSTAT) features:  0.661520770677
#
#
# The R Square Metric using LSTAT and polynomial term(LSTAT*LSTAT) features:  0.551875335414
#
#
# The R Square Metric using LSTAT and polynomial term(LSTAT^2 and LSTAT^3) features:  0.576883354518

# %% [markdown]
# How R-squared metric differs from the previous model without interaction term?
# How does R-squared metric differ in the previous models ?
#
# 2) The interaction term make the prediction more accurate than the model without interaction term.
#
# 5) Adding more polynomial features could help predict the target better to a certain extent.

# %% [markdown]
# <b>Problem #3-8.</b> Fit all features (13 features) in the dataset to a multiple linear regression model, and report<br>
#
# > (1) p-values for each feature.
#
# <b> Answer the following questions:</b>
#
# - What does p-value means
# - What are the important features? <br>

# %%
import statsmodels.formula.api as smf
X = df[['target','RM','LSTAT','CRIM','ZN','INDUS','CHAS','NOX','AGE','DIS','RAD','TAX','PTRATIO','B']]

model=smf.ols('target ~ RM+LSTAT+CRIM+ZN+INDUS+CHAS+NOX+AGE+DIS+RAD+TAX+PTRATIO+B', X)
Fitting_results=model.fit()
print(Fitting_results.summary().tables[1])
print('p-values are: \n', Fitting_results.pvalues)
# Out:
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     36.4911      5.104      7.149      0.000      26.462      46.520
# RM             3.8048      0.418      9.102      0.000       2.983       4.626
# LSTAT         -0.5255      0.051    -10.366      0.000      -0.625      -0.426
# CRIM          -0.1072      0.033     -3.276      0.001      -0.171      -0.043
# ZN             0.0464      0.014      3.380      0.001       0.019       0.073
# INDUS          0.0209      0.061      0.339      0.735      -0.100       0.142
# CHAS           2.6886      0.862      3.120      0.002       0.996       4.381
# NOX          -17.7958      3.821     -4.658      0.000     -25.302     -10.289
# AGE            0.0008      0.013      0.057      0.955      -0.025       0.027
# DIS           -1.4758      0.199     -7.398      0.000      -1.868      -1.084
# RAD            0.3057      0.066      4.608      0.000       0.175       0.436
# TAX           -0.0123      0.004     -3.278      0.001      -0.020      -0.005
# PTRATIO       -0.9535      0.131     -7.287      0.000      -1.211      -0.696
# B              0.0094      0.003      3.500      0.001       0.004       0.015
# ==============================================================================
# p-values are:
#  Intercept    3.182440e-12
# RM           2.207486e-18
# LSTAT        6.595808e-23
# CRIM         1.126402e-03
# ZN           7.836070e-04
# INDUS        7.345971e-01
# CHAS         1.912339e-03
# NOX          4.117296e-06
# AGE          9.546859e-01
# DIS          6.017651e-13
# RAD          5.189664e-06
# TAX          1.117826e-03
# PTRATIO      1.268218e-12
# B            5.072875e-04
# dtype: float64

# %% [markdown]
# RM, LSTAT, NOX, DIS, PTRATIO, and RAD are important. These features are closelier associated with the target because their p value being less than the t value.

# %% [markdown]
# ---

# %% [markdown]
# <h3>  Problem #4. Ordinary Least Square (OLS) [20 points] </h3> <br>

# %% [markdown]
# <b>Problem #4-1.</b>  Ordinary Least Square (OLS), calculate parameters
#
# Follow two steps<br>
#
# - From your DataFrame generate new DataFrame with 2 columns ('LSTAT' and target)
#
# - Using the least squared formula below write a function to calulate $B_0$  and $B_1$  from your new DataFrame where 'LSTAT' = x and target = y. *(hint you can add 2 colums to your DataFrame($x*x$  and  $x*y$), check the problem #2-1)*

# %% [markdown]
# \begin{array} \\
#     \hat{\beta}_0 = \bar{y} - \hat{\beta}_1\bar{x}, \\ \\
#     \hat{\beta}_1 = \frac{\sum_{i=1}^n y_i x_i - \bar{y}\sum_{i=1}^n x_i}{\sum_{i=1}^n x^2 - \bar{x}\sum_{i=1}^n x_i} \\ \\
#     \text{where }\bar{x} = \frac{\sum_{i=1}^y x_i}{n} \text{ and } \bar{y} = \frac{\sum_{i=1}^y y_i}{n} \\
# \end{array}

# %%
#Write your narrative answer here
#taget = pd.DataFrame(dataset.target,columns=["MEDV"])
lstat = pd.DataFrame(dataset.data,columns=dataset.feature_names)["LSTAT"]
dn=pd.concat([taget,lstat],axis=1)
dn.describe(include='all')
# Out:
#              MEDV       LSTAT
# count  506.000000  506.000000
# mean    22.532806   12.653063
# std      9.197104    7.141062
# min      5.000000    1.730000
# 25%     17.025000    6.950000
# 50%     21.200000   11.360000
# 75%     25.000000   16.955000
# max     50.000000   37.970000

# %%
aveX=dn['LSTAT'].sum()/506
aveX
# Out:
# 12.653063241106723

# %%
aveY=dn['MEDV'].sum()/506
aveY
# Out:
# 22.532806324110698

# %%
def culB1(dn):
    aveX=dn['LSTAT'].sum()/506
    aveY=dn['MEDV'].sum()/506
    sumT=0
    sumB=0
    for i in range(0,506):
        x=dn.LSTAT[i]
        y=dn.MEDV[i]
        sumT=sumT+(x-aveX)*(y-aveY)
        sumB=sumB+(x-aveX)*(x-aveX)
    B1=sumT/sumB
    return B1
B1=culB1(dn)
B1
# Out:
# -0.95004935375799049

# %%
def culB0(dn,B1):
    aveX=dn['LSTAT'].sum()/506
    aveY=dn['MEDV'].sum()/506
    B0=aveY-B1*aveX
    return B0
B0= culB0(dn,B1)
B0
# Out:
# 34.553840879383124

# %% [markdown]
# <b>Problem #4-2.</b>  Ordinary Least Square (OLS) <br>
# Using formula below and using $B_0$ and $B_1$ from previous problem calculate $\hat{y}$ $where$ x = 'LSTAT'
# - Add your predicted data to the DataFrame

# %% [markdown]
# \begin{array} \\
#     \hat{y} = \hat{\beta}_0 + \hat{\beta}_1*x, \\ \\
# \end{array}

# %%
#Write your narrative answer here
preY=B0+B1*dn.LSTAT
dn['preY']=preY
dn.describe(include='all')
# Out:
#              MEDV       LSTAT        preY
# count  506.000000  506.000000  506.000000
# mean    22.532806   12.653063   22.532806
# std      9.197104    7.141062    6.784361
# min      5.000000    1.730000   -1.519533
# 25%     17.025000    6.950000   18.445754
# 50%     21.200000   11.360000   23.761280
# 75%     25.000000   16.955000   27.950998
# max     50.000000   37.970000   32.910255

# %% [markdown]
# <b>Problem #4-3.</b>  Verification
#
# Predict $\hat{y}$ using linear regression model *(for this part you don't need to use train test split) *
#
# - Add your predicted data to the DataFrame
#
# Compare 3 column:
# - target
# - predicted column using our own code, ( from problem 4-2)
# - predicted column using linear regression model
#
# Comment your observations

# %%
#Write your narrative answer here
import matplotlib.pyplot as plt
from pandas import read_csv
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import numpy 
from sklearn.metrics import r2_score

X1=dn.LSTAT.values.reshape(-1,1) # define features: horsepower 
Y1=dn.MEDV.values.reshape(-1,1) # define label: miles per gallon

model=LinearRegression()
fitted_model=model.fit(X1,Y1)
predicted_target= fitted_model.predict(X1)

dn['preY2']=predicted_target
dn
# Out:
#      MEDV  LSTAT       preY      preY2
# 0    24.0   4.98  29.822595  29.822595
# 1    21.6   9.14  25.870390  25.870390
# 2    34.7   4.03  30.725142  30.725142
# 3    33.4   2.94  31.760696  31.760696
# 4    36.2   5.33  29.490078  29.490078
# 5    28.7   5.21  29.604084  29.604084
# 6    22.9  12.43  22.744727  22.744727
# 7    27.1  19.15  16.360396  16.360396
# 8    16.5  29.93   6.118864   6.118864
# 9    18.9  17.10  18.307997  18.307997
# 10   15.0  20.45  15.125332  15.125332
# 11   18.9  13.27  21.946686  21.946686
# 12   21.7  15.71  19.628566  19.628566
# 13   20.4   8.26  26.706433  26.706433
# 14   18.2  10.26  24.806335  24.806335
# 15   19.9   8.47  26.506923  26.506923
# 16   23.1   6.58  28.302516  28.302516
# 17   17.5  14.67  20.616617  20.616617
# 18   20.2  11.69  23.447764  23.447764
# 19   18.2  11.28  23.837284  23.837284
# 20   13.6  21.02  14.583803  14.583803
# 21   19.6  13.83  21.414658  21.414658
# 22   15.2  18.72  16.768917  16.768917
# 23   14.5  19.88  15.666860  15.666860
# 24   15.6  16.30  19.068036  19.068036
# 25   13.9  16.51  18.868526  18.868526
# 26   16.6  14.81  20.483610  20.483610
# 27   14.8  17.28  18.136988  18.136988
# 28   18.4  12.80  22.393209  22.393209
# 29   21.0  11.98  23.172250  23.172250
# ..    ...    ...        ...        ...
# 476  16.7  18.68  16.806919  16.806919
# 477  12.0  24.91  10.888111  10.888111
# 478  14.6  18.03  17.424451  17.424451
# 479  21.4  13.11  22.098694  22.098694
# 480  23.0  10.74  24.350311  24.350311
# 481  23.7   7.74  27.200459  27.200459
# 482  25.0   7.01  27.893995  27.893995
# 483  21.8  10.42  24.654327  24.654327
# 484  20.6  13.34  21.880183  21.880183
# 485  21.2  10.58  24.502319  24.502319
# 486  19.1  14.98  20.322102  20.322102
# 487  20.6  11.45  23.675776  23.675776
# 488  15.2  18.06  17.395950  17.395950
# 489   7.0  23.97  11.781158  11.781158
# 490   8.1  29.68   6.356376   6.356376
# 491  13.6  18.07  17.386449  17.386449
# 492  20.1  13.35  21.870682  21.870682
# 493  21.8  12.01  23.143748  23.143748
# 494  24.5  13.59  21.642670  21.642670
# 495  23.1  17.60  17.832972  17.832972
# 496  19.7  21.14  14.469798  14.469798
# 497  18.3  14.10  21.158145  21.158145
# 498  21.2  12.92  22.279203  22.279203
# 499  17.5  15.10  20.208096  20.208096
# 500  16.8  14.33  20.939634  20.939634
# 501  22.4   9.67  25.366864  25.366864
# 502  20.6   9.08  25.927393  25.927393
# 503  23.9   5.64  29.195563  29.195563
# 504  22.0   6.48  28.397521  28.397521
# 505  11.9   7.88  27.067452  27.067452
#
# [506 rows x 4 columns]

# %% [markdown]
# The predicted data from my own code is same as the data from using linear regression model. So, it means the linear regression model use same mothed we have used.

# %% [markdown]
# ### Submission
# Once you complete the assignment, <br>
# Name your file in the format of <b style='color:red'>LASTNAME-PITTID-Assignment1.ipynb</b>, and submit it on the courseweb
